# %% [markdown]
# # Introducción a Python – Cuaderno de Ejercicios
#
# Este cuaderno está organizado en apartados. Cada sección contiene teoría breve, ejemplos básicos y **ejercicios detallados** para que resuelvas directamente en las celdas de código.

# %% [markdown]
# ## 1. Fundamentos y Sintaxis
# ### Teoría
# - Variables, tipos de datos básicos (`int`, `float`, `str`, `bool`).
# - Operadores aritméticos, lógicos y de comparación.
# - Entrada y salida de datos (`input`, `print`).

# %%
# Ejemplo: suma simple
x = 5
y = 3
print('Suma:', x + y)

# %% [markdown]
# ### Ejercicio 1: Presentación personal
# Escribe un programa que pida al usuario su **nombre** y su **edad**.
# El programa debe mostrar un mensaje de saludo y calcular cuántos años tendrá dentro de 10 años.
#
# **Ejemplo de ejecución:**
# ```
# Introduce tu nombre: Ana
# Introduce tu edad: 20
# Hola Ana, dentro de 10 años tendrás 30.
# ```

# %%
# Escribe aquí tu solución

# %% [markdown]
# ### Ejercicio 2: Calculadora simple
# Crea un programa que pida **dos números** y muestre en pantalla:
# - La suma
# - La resta
# - La multiplicación
# - La división
#
#  Nota: asegúrate de mostrar resultados claros y legibles.

# %%
# Escribe aquí tu solución

# %% [markdown]
# ### Ejercicio 3: Conversor de temperaturas
# Haz un programa que convierta de grados **Celsius a Fahrenheit** y de **Fahrenheit a Celsius**.
# - Pide al usuario una temperatura y la escala de origen.
# - Devuelve la conversión correcta.
#
# Fórmulas:
# - °F = (°C × 9/5) + 32
# - °C = (°F − 32) × 5/9

# %%
# Escribe aquí tu solución

# %% [markdown]
# ## 2. Control de Flujo
# ### Teoría
# - Condicionales: `if`, `elif`, `else`.
# - Bucles: `for`, `while`, `break`, `continue`.

# %%
# Ejemplo: condicional simple
numero = 10
if numero > 0:
    print('El número es positivo')

# %% [markdown]
# ### Ejercicio 4: Número par o impar
# Escribe un programa que pida un número entero y muestre si es **par** o **impar**.

# %%
# Escribe aquí tu solución

# %% [markdown]
# ### Ejercicio 5: FizzBuzz
# Imprime los números del 1 al 50 con las siguientes reglas:
# - Si es múltiplo de 3, escribe 'Fizz'.
# - Si es múltiplo de 5, escribe 'Buzz'.
# - Si es múltiplo de ambos, escribe 'FizzBuzz'.
# - En caso contrario, imprime el número.

# %%
# Escribe aquí tu solución

# %% [markdown]
# ### Ejercicio 6: Juego del número secreto
# Crea un programa que genere un número secreto aleatorio entre 1 y 20.
# El usuario debe adivinarlo, recibiendo pistas de 'más alto' o 'más bajo'.
# El juego termina cuando acierta.

# %%
# Escribe aquí tu solución

# %% [markdown]
# ### Ejercicio 7: Tablas de multiplicar
# Escribe un programa que pida un número entero y muestre su **tabla de multiplicar** del 1 al 10.

# %%
# Escribe aquí tu solución

# %% [markdown]
# ## 3. Colecciones
# ### Teoría
# - Listas, tuplas, diccionarios y conjuntos.
# - Indexación, slicing y métodos básicos.

# %%
# Ejemplo: lista de notas
notas = [5, 7, 9]
print('Media:', sum(notas)/len(notas))

# %% [markdown]
# ### Ejercicio 8: Gestión de notas
# Escribe un programa que pida al usuario **5 notas** y las almacene en una lista.
# Debe mostrar:
# - La media de las notas.
# - La nota más alta.
# - La nota más baja.
# → Extensión opcional: mostrar las notas de mayor a menor.

# %%
# Escribe aquí tu solución

# %% [markdown]
# ### Ejercicio 9: Agenda de contactos
# Crea un programa que permita guardar contactos en un diccionario con la estructura:
# `nombre -> teléfono, email`
#
# Debe permitir:
# - Añadir un nuevo contacto.
# - Buscar un contacto por nombre.
# - Mostrar todos los contactos guardados.

# %%
# Escribe aquí tu solución

# %% [markdown]
# ### Ejercicio 10: Eliminar duplicados
# Dada una lista de palabras (con posibles repeticiones), usa un **set** para eliminar duplicados y mostrar el resultado.

# %%
# Escribe aquí tu solución

# %% [markdown]
# ## 4. Funciones
# ### Teoría
# - Definición con `def`.
# - Parámetros y valores de retorno.
# - Funciones lambda.

# %%
# Ejemplo: función para convertir divisas
def euros_a_dolares(euros):
    return euros * 1.1

print(euros_a_dolares(10))

# %% [markdown]
# ### Ejercicio 11: Área de un círculo
# Define una función que reciba el radio de un círculo y devuelva su área.
# Usa la fórmula: área = π × r² (puedes importar `math`).

# %%
# Escribe aquí tu solución

# %% [markdown]
# ### Ejercicio 12: Conversor de divisas
# Implementa funciones que conviertan **euros** a:
# - Dólares
# - Libras
# - Yenes
#
# El usuario debe introducir una cantidad y la moneda destino.

# %%
# Escribe aquí tu solución

# %% [markdown]
# ### Ejercicio 13: Filtrado con funciones
# Dada una lista de números del 1 al 20:
# - Usa `filter` y `lambda` para obtener los números pares.
# - Usa `map` para elevarlos al cuadrado.

# %%
# Escribe aquí tu solución

# %% [markdown]
# ## 5. Manejo de Errores
# ### Teoría
# - Uso de `try`, `except`, `finally`.
# - Errores comunes: división por cero, entradas inválidas.

# %%
# Ejemplo: manejo de excepción
def division(a, b):
    try:
        return a / b
    except ZeroDivisionError:
        return 'No se puede dividir entre cero'

print(division(10,0))

# %% [markdown]
# ### Ejercicio 14: Calculadora robusta
# Mejora tu calculadora para que controle:
# - División por cero.
# - Entrada de texto en lugar de números.

# %%
# Escribe aquí tu solución

# %% [markdown]
# ## 6. Archivos
# ### Teoría
# - Lectura y escritura con `open()`.
# - Modos: `r`, `w`, `a`.

# %%
# Ejemplo: escritura y lectura
with open('ejemplo.txt', 'w') as f:
    f.write('Hola mundo')

with open('ejemplo.txt', 'r') as f:
    print(f.read())

# %% [markdown]
# ### Ejercicio 15: Procesador de texto
# Crea un programa que lea un archivo `.txt` y muestre:
# - Número de líneas
# - Número de palabras
# - Número de caracteres

# %%
# Escribe aquí tu solución

# %% [markdown]
# ### Ejercicio 16: Guardar notas en archivo
# Escribe un programa que pida al usuario las notas de varios alumnos y las guarde en un fichero.
# Cada línea debe contener: `nombre, nota`.

# %%
# Escribe aquí tu solución

# %% [markdown]
# ## 7. Programación Orientada a Objetos
# ### Teoría
# - Clases, objetos, atributos y métodos.
# - Constructor `__init__`.

# %%
# Ejemplo: clase simple
class Coche:
    def __init__(self, marca, modelo):
        self.marca = marca
        self.modelo = modelo

    def mostrar_info(self):
        print(f'Coche: {self.marca} {self.modelo}')

mi_coche = Coche('Toyota', 'Corolla')
mi_coche.mostrar_info()

# %% [markdown]
# ### Ejercicio 17: Clase Coche
# Crea una clase `Coche` con atributos: marca, modelo, año y color.
# Incluye un método que muestre la información completa.

# %%
# Escribe aquí tu solución

# %% [markdown]
# ### Ejercicio 18: Biblioteca
# Crea una clase `Libro` con atributos `título`, `autor` y `año`.
# Crea también una clase `Biblioteca` que permita:
# - Añadir libros
# - Buscar libros por título
# - Listar todos los libros

# %%
# Escribe aquí tu solución

# %% [markdown]
# ### Ejercicio 19: Clase Estudiante
# Crea una clase `Estudiante` con atributos `nombre`, `edad` y `notas` (lista).
# Incluye un método que calcule la nota media.

# %%
# Escribe aquí tu solución

# %% [markdown]
# ## 8. Mini Proyectos
# ### Proyecto 1: Gestor de tareas
# Crea un programa en consola que permita:
# - Añadir tareas
# - Listar tareas pendientes
# - Marcar tareas como completadas
# - Eliminar tareas

# %%
# Escribe aquí tu solución

# %% [markdown]
# ### Proyecto 2: Juego de Piedra, Papel o Tijera
# Crea un juego donde el usuario juegue contra la máquina.
# - Usa `random.choice()` para la jugada de la máquina.
# - Decide el ganador según las reglas clásicas.

# %%
# Escribe aquí tu solución

# %% [markdown]
# ### Proyecto 3: Analizador de texto
# Escribe un programa que lea un archivo `.txt` y muestre:
# - Palabras más frecuentes
# - Número total de frases
# - Longitud media de las palabras

# %%
# Escribe aquí tu solución

# %% [markdown]
# ## 9. Herencia en POO
# ### Teoría
# - La **herencia** permite que una clase (hija) reutilice atributos y métodos de otra clase (padre).
# - Se usa para evitar repetir código y crear jerarquías de objetos.
# - Sintaxis básica: `class Hija(Padre): ...`

# %%
# Ejemplo: herencia simple
class Vehiculo:
    def __init__(self, marca):
        self.marca = marca

    def mover(self):
        print(f'El vehículo {self.marca} se mueve')

class Coche(Vehiculo):
    def __init__(self, marca, puertas):
        super().__init__(marca)
        self.puertas = puertas

    def mover(self):
        print(f'El coche {self.marca} avanza sobre ruedas')

v = Vehiculo('Genérico')
v.mover()

c = Coche('Toyota', 4)
c.mover()

# %% [markdown]
# ### Ejercicio 20: Empleados y Programadores
# Crea una clase `Empleado` con atributos `nombre` y `salario`.
# Luego crea una clase `Programador` que herede de `Empleado` y añada el atributo `lenguaje`.
#
# Requisitos:
# - Método `mostrar_info()` que muestre todos los datos.
# - Permitir crear varios empleados y programadores, y mostrarlos por pantalla.

# %%
# Escribe aquí tu solución
